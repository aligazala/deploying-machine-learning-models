# %%
import dtale
import pandas as pd

# %%
dtale.show(pd.read_csv("train.csv"))
# Out:
# /home/ali/anaconda3/lib/python3.9/site-packages/dtale/views.py:755: FutureWarning:
#
# ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://ali-Lenovo-V15-IIL:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# /home/ali/anaconda3/lib/python3.9/site-packages/dtale/views.py:1990: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /home/ali/anaconda3/lib/python3.9/site-packages/dtale/views.py:1990: FutureWarning:
#
# ...
